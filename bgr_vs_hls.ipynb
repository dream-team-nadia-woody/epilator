# %%
# import data libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import modules
import video.df as df
import video.exploration as ex
from importlib import reload

# %%
import video.reader as r
import cv2 as cv
from video.reader import VideoReader

from typing import List, Union
from numpy.typing import ArrayLike

# %% [markdown]
# Plan:
# - Create a function to extract diff of BGR sum in numpy. Steps:
# 1. Mean values of every channel per frame `df.groupby('frame').blue.mean()`
# 2. Sum of those values
#
# - For every video:
# 1. Extract normalized lightness difference
# 2. Extract normalized sum of bgr channels differnce
# 3. Print the name of file and BGR or Ligtness
# 4. Print the results of zero crossing frames
# 5. Print the result of hazard seconds

# %%
# function to extract the difference of bgr sum
def get_bgr_sum_diff(vid: Union[str, ArrayLike]) -> np.array:
    '''
    parameters:
        path: string -> path to the video
    returns:
        a numpy array with a difference in the sum of values of the 3 channels in the video:
    blue, green and red channels
    '''
    if isinstance(vid, str):
        vid, fps = VideoReader.get_vid(vid, 0)
    #frames = vid.shape[0]
    height = vid.shape[1]
    width = vid.shape[2]
    # get the average result of sum of all bgr values per frame
    avg_bgr = vid.reshape(-1, 3).sum(axis=1).reshape(-1, height*width).mean(axis = 1)
    # get the difference cd (for color difference)
    cd = np.diff(avg_bgr, 1)
    # normalize the difference, all values should be between -0.5 and 0.5
    cd = (cd - cd.min())/(cd.max() - cd.min()) - 0.5

    return cd, fps

# %%
path = 'videos/Banned Pokemon Seizure Scene.mp4'

# %%
if isinstance(path, str):
    vid, fps = VideoReader.get_vid(path, 0)
frames = vid.shape[0]
height = vid.shape[1]
width = vid.shape[2]

# %%
frames, height, width
# Out:
# (785, 100, 100)

# %%
# framesm height, width, channels
vid.shape
# Out:
# (785, 100, 100, 3)

# %%
# every single pixel with its BGR values
vid.reshape(-1, 3) # shape (7850000, 3)
# Out:
# array([[36, 36, 36],
#        [34, 34, 34],
#        [32, 32, 32],
#        ...,
#        [44, 29, 25],
#        [44, 29, 25],
#        [44, 29, 25]], dtype=uint8)

# %%
# sum of BGR values for every pixel
vid.reshape(-1, 3).sum(axis=1) # shape (7850000,)
# Out:
# array([108, 102,  96, ...,  98,  98,  98], dtype=uint64)

# %%
# array of sum of BGR values of every pixel in the frame
vid.reshape(-1, 3).sum(axis=1).reshape(-1, height*width) # shape (785, 10000)
# Out:
# array([[108, 102,  96, ..., 398, 399, 393],
#        [108, 102,  96, ..., 398, 399, 393],
#        [108, 102,  96, ..., 398, 399, 393],
#        ...,
#        [108, 108, 108, ...,  96,  98,  98],
#        [108, 108, 108, ...,  98,  98,  98],
#        [108, 108, 108, ...,  98,  98,  98]], dtype=uint64)

# %%
vid.reshape(-1, 3).sum(axis=1).reshape(-1, height*width).mean(axis = 1) # shape (785,)
# Out:
# array([314.2295, 314.2142, 314.1625, 314.0782, 313.9871, 313.9558,
#        313.935 , 313.9361, 313.9446, 313.9484, 313.9413, 313.9346,
#        313.9444, 313.974 , 313.9556, 313.8789, 313.8402, 313.8243,
#        313.7907, 313.7877, 313.7757, 313.7766, 313.7686, 313.7626,
#        313.7541, 313.6841, 313.6594, 313.6091, 313.5222, 313.484 ,
#        313.3756, 313.3247, 313.2317, 313.222 , 313.2315, 313.2282,
#        313.2175, 313.2377, 313.2245, 313.2318, 313.2245, 313.2318,
#        313.2242, 313.2503, 313.2165, 313.2195, 313.2171, 313.2089,
#        313.1711, 313.1906, 313.2462, 313.1511, 313.1345, 313.1458,
#        313.1195, 313.1039, 313.1234, 313.1004, 313.1164, 313.169 ,
#        313.1773, 313.1724, 313.1122, 313.0861, 313.0303, 313.0344,
#        313.0445, 313.0416, 313.0305, 313.0428, 313.0305, 313.0428,
#        313.0276, 313.0412, 313.0658, 313.0225, 313.0542, 313.035 ,
#        313.0105, 312.9339, 312.9537, 312.94  , 312.9435, 312.9259,
#        312.8988, 312.9006, 312.8799, 312.8908, 312.8868, 312.9025,
#        312.8744, 312.8737, 312.8504, 312.859 , 312.8596, 312.8402,
#        312.83  , 312.8501, 312.8398, 312.8297, 312.8917, 312.9368,
#        312.9257, 312.9228, 312.9195, 312.9054, 312.9088, 312.8911,
#        312.8927, 312.8723, 312.8781, 312.862 , 312.9302, 312.8573,
#        312.8751, 312.8579, 312.8656, 312.8647, 312.8867, 312.8776,
#        313.2743, 313.2481, 313.2286, 313.1993, 313.2015, 313.1834,
#        313.1139, 313.0331, 313.051 , 312.9988, 312.9756, 312.9614,
#        312.9838, 312.9642, 312.994 , 312.9723, 312.9869, 312.9517,
#        312.9751, 312.9477, 312.9706, 312.9606, 312.9985, 313.0068,
#        312.9137, 312.9029, 312.8979, 312.9092, 312.8991, 312.9156,
#        313.023 , 313.0783, 313.0178, 313.0444, 313.0378, 313.0337,
#        313.0339, 313.059 , 313.0523, 313.1083, 313.1003, 313.1351,
#        313.1645, 313.1656, 313.1638, 313.1597, 313.166 , 313.1735,
#        313.1825, 313.1818, 313.1906, 313.1784, 313.1958, 313.1873,
#        313.1975, 313.2443, 313.2178, 313.2141, 313.1997, 313.2025,
#        313.3952, 313.3453, 313.3357, 313.3236, 313.2577, 313.2594,
#        313.2532, 313.2604, 313.2652, 313.2691, 313.2659, 313.2791,
#        313.2492, 313.2487, 313.2445, 313.2533, 313.245 , 313.2474,
#        313.2488, 313.26  , 313.2522, 313.2287, 313.1757, 313.1904,
#        313.1353, 313.131 , 313.0844, 313.1111, 313.065 , 313.0681,
#        313.0725, 313.0656, 313.0527, 313.0421, 313.0235, 313.0291,
#        313.0231, 313.0291, 313.0231, 313.0267, 313.0228, 313.0267,
#        313.0262, 313.0182, 313.0209, 313.4908, 313.1106, 313.368 ,
#        314.8801, 314.9023, 315.0615, 315.1343, 314.4619, 315.7621,
#        315.9333, 315.9079, 315.9192, 315.4417, 316.5612, 316.6384,
#        304.1924, 303.0096, 305.5415, 305.5881, 305.2608, 305.2943,
#        305.8758, 308.7402, 308.9208, 308.9158, 310.335 , 310.0398,
#        310.4381, 311.0906, 311.3318, 311.3956, 311.3299, 311.9543,
#        312.4205, 312.3767, 312.2767, 312.1688, 312.1528, 311.4527,
#        311.3656, 310.9219, 310.6833, 309.085 , 308.9474, 308.824 ,
#        308.8221, 308.7748, 308.7911, 310.6257, 311.0555, 311.05  ,
#        311.0064, 310.9884, 311.4942, 311.6675, 311.863 , 312.1979,
#        311.9152, 311.9496, 312.3909, 312.1452, 312.3816, 312.2892,
#        313.3037, 567.5271, 567.6104, 570.7414, 569.9433, 598.4094,
#        598.9921, 599.396 , 588.1564, 588.2762, 588.5741, 607.379 ,
#        607.3722, 607.5673, 598.5343, 615.5255, 615.6527, 615.865 ,
#        603.4327, 603.6652, 618.6897, 618.6117, 618.4994, 606.8522,
#        606.6308, 606.7166, 617.7163, 617.473 , 617.2275, 606.3087,
#        616.7975, 616.352 , 615.8588, 608.6703, 608.5419, 608.3912,
#        616.3102, 615.8457, 615.3641, 611.3918, 611.3816, 616.4021,
#        616.2525, 616.1166, 612.934 , 612.5604, 617.0197, 615.2506,
#        361.1658, 361.0486, 359.2005, 361.6133, 362.5846, 363.2416,
#        364.1349, 365.7364, 365.4085, 365.6466, 365.4462, 367.2664,
#        367.0779, 368.7533, 369.7327, 369.7733, 369.968 , 372.6771,
#        362.064 , 362.0058, 364.1076, 365.6806, 365.6463, 359.3184,
#        359.7252, 359.6183, 367.5041, 367.4551, 367.538 , 366.9664,
#        366.7479, 348.7441, 335.6932, 307.3419, 307.2444, 307.1179,
#        243.2356, 210.0109, 188.9442, 171.0465, 155.3133, 154.9358,
#        133.2046, 132.83  , 140.5061, 140.3976, 151.1124, 150.9813,
#        150.3346, 149.6407, 150.8523, 150.8848, 150.8924, 150.819 ,
#        149.7757, 149.6669, 149.7218, 147.8895, 147.9467, 147.8531,
#        149.3487, 149.2941, 149.2692, 149.2654, 149.1576, 150.0214,
#        150.0369, 150.13  , 150.3727, 150.3918, 151.    , 562.8703,
#         67.0861, 576.1425, 576.0236, 335.4796, 335.2415, 318.4142,
#        317.9703, 323.5498, 323.0489, 322.8128, 330.499 , 330.3562,
#        315.6931, 315.219 , 320.7097, 320.3572, 320.2275, 320.1294,
#        329.1687, 314.6994, 314.5739, 314.4505, 320.1468, 320.0503,
#        319.995 , 328.6959, 328.696 , 313.7359, 313.6927, 183.0961,
#        182.9879, 186.2333, 187.8939, 188.1288, 213.547 , 213.638 ,
#        213.7183, 213.725 , 257.8092, 259.3536, 259.3358, 411.0169,
#        412.4477, 412.3624, 436.6437, 436.6571, 430.1673, 430.0703,
#        429.0859, 725.6934, 725.5797, 725.4217, 725.3558, 293.2798,
#         48.3692, 274.2801, 460.9065, 274.2854, 460.077 , 460.0057,
#        274.0833, 462.6061, 270.5898, 461.6173, 461.5992, 270.5989,
#        455.8614, 455.8664, 453.2075, 268.7977, 449.9542, 449.9458,
#        449.9165, 263.9117, 264.4306, 431.9523, 431.9921, 261.4719,
#        261.3539, 432.7639, 428.3982, 428.2031, 261.9745, 419.0434,
#        263.1945, 263.0841, 405.8925, 257.5869, 402.9718, 253.7571,
#        395.2504, 395.0514, 394.9825, 253.6944, 387.4734, 250.8327,
#        380.3073, 380.2752, 244.5341, 244.4374, 241.5427, 370.0881,
#        370.0965, 237.8247, 357.9417, 352.7056, 352.5537, 352.5071,
#        231.3374, 344.3747, 227.4857, 227.1842, 344.5203, 229.0839,
#        340.7602, 229.4875, 340.1365, 226.7379, 226.6628, 339.5707,
#        226.0033, 342.7082, 342.7713, 341.8038, 230.0139, 229.942 ,
#        339.4452, 339.4359, 227.5239, 228.013 , 340.4518, 340.4144,
#        340.4122, 226.9799, 339.1383, 340.201 , 340.2654, 227.1068,
#        340.2955, 340.3581, 227.6256, 337.7943, 225.3354, 341.3122,
#        228.2452, 342.1218, 342.1322, 226.4004, 336.9902, 227.2219,
#        475.3249, 475.3043, 475.3202, 475.6175, 479.0477, 269.2821,
#        474.0316, 473.9549, 269.414 , 269.4675, 269.4607, 479.0589,
#        479.0542, 271.6264, 475.4998, 475.4593, 478.8585, 478.9412,
#        291.145 , 489.2651, 331.4542, 493.6601, 493.6334, 332.9226,
#        485.0527, 355.2791, 479.8649, 479.6287, 329.4369, 328.8197,
#        281.6823, 276.0489, 275.834 , 275.6483, 369.9634, 371.8495,
#        371.7359, 371.7319, 372.6025, 373.1802, 374.5781, 374.5547,
#        375.7306, 375.8406, 376.1153, 377.4493, 378.1027, 379.2481,
#        380.3777, 381.7728, 381.9872, 382.2775, 383.1522, 383.4068,
#        384.2764, 384.4621, 384.3893, 384.3422, 385.3492, 386.5425,
#        386.6603, 386.6373, 387.9706, 387.9757, 387.8899, 388.6634,
#        388.6499, 388.6485, 388.6513, 149.6892, 148.2502, 148.1364,
#        147.9999, 147.9759, 147.8684, 145.3612, 145.3291, 145.2682,
#        145.2886, 151.9558, 151.9339, 151.7454, 150.3817, 150.2791,
#        150.2253, 150.2666, 150.2834, 144.7527, 144.7324, 147.1021,
#        147.1525, 147.1151, 141.937 , 165.5283, 141.8077, 155.3301,
#        141.8605, 141.8518, 164.2145, 143.0592, 148.1892, 142.7109,
#        166.6691, 166.7245, 166.7236, 143.212 , 156.5339, 164.2311,
#        143.937 , 224.683 , 224.6579, 224.6227, 224.6125, 182.968 ,
#        232.0583, 232.0311, 232.0671, 232.3852, 265.617 , 225.1293,
#        318.221 , 245.9495, 245.7954, 245.7597, 354.5137, 354.521 ,
#        377.9406, 571.1303, 584.2971, 593.0958, 593.3336, 625.7993,
#        625.9824, 628.1056, 673.2776, 673.4997, 673.5674, 673.528 ,
#        680.7654,  75.6853, 657.4839, 657.4788, 445.9176, 448.2795,
#        448.2519, 616.4849, 314.0749, 313.1497, 315.2626, 144.6329,
#        143.9544, 143.9314, 144.7441, 144.7455, 343.3638, 151.8008,
#        301.1673, 119.5855, 119.4278, 119.1579, 130.3008, 130.1756,
#        130.0964, 131.0179, 131.3468, 131.3478, 131.3697, 323.169 ,
#        128.0693, 128.8904, 128.795 , 128.7615, 114.6262, 114.8999,
#        127.0207, 126.8968, 126.4631, 126.4297, 127.0837, 127.0582,
#        132.471 , 132.5954, 126.5052, 125.3594, 125.3459, 126.5935,
#        126.5769, 302.6943, 119.5116, 118.8877, 130.1793, 130.1281,
#        129.9938, 129.9811, 131.7241, 131.7453, 131.7637, 131.8299,
#        131.7575, 317.6868, 138.4229, 138.998 , 124.053 , 123.9632,
#        134.6718, 134.3657, 134.2018, 133.5664, 133.8072, 133.0285,
#        131.9455, 131.5844, 131.3382, 124.668 , 123.3099, 124.4924,
#        111.901 , 112.0337, 111.5341, 111.5063, 124.9872, 125.0082,
#        124.9637, 126.4399, 126.3912, 126.7122, 126.7111])

# %%
avg_bgr = vid.reshape(-1, 3).sum(axis=1).reshape(-1, height*width).mean(axis = 1)

# %%
avg_bgr1 = np.mean(vid.reshape(-1, 3)[:, 0].reshape((-1, height*width)), axis=1) + \
np.mean(vid.reshape(-1, 3)[:, 1].reshape((-1, height*width)), axis=1) + \
np.mean(vid.reshape(-1, 3)[:, 2].reshape((-1, height*width)), axis=1)

# %%
# create the mean of sum values of all channels provides same results as sum of mean values of every channel
np.sum(np.round(avg_bgr, 1) == np.round(avg_bgr1, 1))
# Out:
# 785
