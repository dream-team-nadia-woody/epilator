# %%
import warnings
from importlib import reload

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from video import vid as v
from video import videolike as vl
from video.conversion import Conversions
from video import channel as c

# %%
warnings.simplefilter("ignore")
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
reload(v)
reload(vl)
reload(c)
vid = v.Video.from_file('videos/They Sent the Wrong Burger King Ad💀.mp4',Conversions.HSV)
fig,axs = plt.subplots(2,1)
axs[0].plot(vid.pct_change(1,agg='sum'))
axs[1].plot(vid.hue.pct_change(1,agg='sum'))
axs[1].plot(vid.saturation.pct_change(1,agg='sum'))
axs[1].plot(vid.value.pct_change(1,agg='sum'))
# Out:
# 852

# %%
assert(
    vid.mask() 
)
